# %%
import fotoapp

fotoapp.iniciar_app()
# Out:
# --- BIENVENIDO A FOTOAPP (Versión Módulo) ---
#
# MENÚ DE OPCIONES:
# 1. Cargar y Redimensionar imagen
# 2. Ajustar Contraste (Histograma)
# 3. Aplicar un Filtro
# 4. Crear Boceto para Pintores
# 5. Salir
#
# Ingresa el número de la opción: 5
# ¡Gracias por usar FotoApp! Cerrando programa...
